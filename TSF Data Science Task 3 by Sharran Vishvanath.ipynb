# %%
#
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('C:/Users/hp/Downloads/Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
SepalLengthCm = data['SepalLengthCm']
SepalWidthCm = data['SepalWidthCm']
PetalLengthCm = data['PetalLengthCm']
PetalWidthCm = data['PetalWidthCm']

columns = [SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm]

fig,ax = plt.subplots()
ax.boxplot(columns,notch=True,patch_artist=True)
plt.xticks([1,2,3,4],['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])
# Out:
# ([<matplotlib.axis.XTick at 0x1e121b71bb0>,
#   <matplotlib.axis.XTick at 0x1e121c35100>,
#   <matplotlib.axis.XTick at 0x1e121c50250>,
#   <matplotlib.axis.XTick at 0x1e121c9b700>],
#  [Text(1, 0, 'SepalLengthCm'),
#   Text(2, 0, 'SepalWidthCm'),
#   Text(3, 0, 'PetalLengthCm'),
#   Text(4, 0, 'PetalWidthCm')])

# %%
Q1 = data['SepalWidthCm'].quantile(0.25)
Q3 = data['SepalWidthCm'].quantile(0.75)
IQR = Q3 - Q1

ur = Q3+1.5*IQR
lr = Q1-1.5*IQR

samp = data.index[data['SepalWidthCm'] > ur]
samp.append(data.index[data['SepalWidthCm'] < lr])
data = data.drop(samp)
data.reset_index(drop=True)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 142  146            6.7           3.0            5.2           2.3
# 143  147            6.3           2.5            5.0           1.9
# 144  148            6.5           3.0            5.2           2.0
# 145  149            6.2           3.4            5.4           2.3
# 146  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
#
# [147 rows x 6 columns]

# %%
df = data.copy()
x = df.iloc[:,1:5]
y = df.iloc[:,-1]

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score

clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy*100
# Out:
# 97.2972972972973

# %%
data = {'y_Actual': y_test,
        'y_Predicted': y_pred
        }

df = pd.DataFrame(data)
df.reset_index(inplace = True, drop = True)
df.head()
# Out:
#           y_Actual      y_Predicted
# 0   Iris-virginica   Iris-virginica
# 1  Iris-versicolor  Iris-versicolor
# 2   Iris-virginica   Iris-virginica
# 3      Iris-setosa      Iris-setosa
# 4   Iris-virginica   Iris-virginica

# %%
confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)
# Out:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica
# Actual
# Iris-setosa               14                0               0
# Iris-versicolor            0                9               1
# Iris-virginica             0                0              13

# %%
sns.heatmap(confusion_matrix, annot=True)
plt.show()

# %%
from sklearn import tree
feature_names = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
class_names = ['Iris-setosa','Iris-versicolor','Iris-virginica']
fig,ax = plt.subplots(nrows=1,ncols=1,figsize=(4,4),dpi=300,facecolor='k')
tree.plot_tree(clf,feature_names=feature_names,class_names=class_names,filled=True);
fig.savefig('IrisTree.png')

# %%
clf.predict_proba([[4.7,3.2,1.3,0.2]])
# Out:
# array([[1., 0., 0.]])

# %%
clf.predict([[4.7,3.2,1.3,0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
print("Hence, the Decision Tree Model has been created and visualized with the accuracy of 97.29% in the Test dataset. It also predict the class of the new data successfully.")
# Out:
# Hence, the Decision Tree Model has been created and visualized with the accuracy of 97.29% in the Test dataset. It also predict the class of the new data successfully.
